# %%
import polars as pl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.metrics import classification_report, roc_auc_score, precision_recall_curve, auc
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.calibration import calibration_curve

import warnings
warnings.filterwarnings('ignore')

# %%
df = pl.read_csv('/kaggle/input/unlaveled-data/unlabeled_data_revised.csv', separator=";")
df
# Out:
# shape: (1_109, 6)
# ┌─────────────────┬─────────────────────────────┬─────────────┬───────────┬────────────┬───────────┐
# │ from_username   ┆ profile_link                ┆ account_age ┆ is_buzzer ┆ total_post ┆ followers │
# │ ---             ┆ ---                         ┆ ---         ┆ ---       ┆ ---        ┆ ---       │
# │ str             ┆ str                         ┆ i64         ┆ i64       ┆ i64        ┆ i64       │
# ╞═════════════════╪═════════════════════════════╪═════════════╪═══════════╪════════════╪═══════════╡
# │ Ayudihutankecil ┆ https://twitter.com/Ayudihu ┆ 9           ┆ 1         ┆ 20100      ┆ 641       │
# │                 ┆ tan…                        ┆             ┆           ┆            ┆           │
# │ bang_ouz71      ┆ https://twitter.com/bang_ou ┆ 7           ┆ 1         ┆ 2292       ┆ 15        │
# │                 ┆ z71                         ┆             ┆           ┆            ┆           │
# │ KowuLaode341884 ┆ https://twitter.com/KowuLao ┆ 2           ┆ 1         ┆ 10100      ┆ 98        │
# │                 ┆ de3…                        ┆             ┆           ┆            ┆           │
# │ Manusia2B       ┆ https://twitter.com/Manusia ┆ 4           ┆ 1         ┆ 89700      ┆ 669       │
# │                 ┆ 2B                          ┆             ┆           ┆            ┆           │
# │ PutraMahes59    ┆ https://twitter.com/PutraMa ┆ 2           ┆ 0         ┆ 2586       ┆ 58        │
# │                 ┆ hes…                        ┆             ┆           ┆            ┆           │
# │ …               ┆ …                           ┆ …           ┆ …         ┆ …          ┆ …         │
# │ suaradotcom     ┆ https://twitter.com/suarado ┆ 0           ┆ 3         ┆ 0          ┆ 33320     │
# │                 ┆ tco…                        ┆             ┆           ┆            ┆           │
# │ kba_news        ┆ https://twitter.com/kba_new ┆ 0           ┆ 3         ┆ 0          ┆ 9657      │
# │                 ┆ s                           ┆             ┆           ┆            ┆           │
# │ BustoniFikri4   ┆ https://twitter.com/Bustoni ┆ 5           ┆ 1         ┆ 4106       ┆ 66        │
# │                 ┆ Fik…                        ┆             ┆           ┆            ┆           │
# │ SETYAKI22965702 ┆ https://twitter.com/SETYAKI ┆ 4           ┆ 1         ┆ 108900     ┆ 21413     │
# │                 ┆ 229…                        ┆             ┆           ┆            ┆           │
# │ Venus19702      ┆ https://twitter.com/Venus19 ┆ 5           ┆ 1         ┆ 13000      ┆ 53        │
# │                 ┆ 702                         ┆             ┆           ┆            ┆           │
# └─────────────────┴─────────────────────────────┴─────────────┴───────────┴────────────┴───────────┘

# %% [markdown]
# ## Process Dataframe

# %%
df_cleaned = df.filter((pl.col("is_buzzer") != 3) & (pl.col("is_buzzer") != 9))
df_cleaned = df_cleaned.with_columns([
    # Per year (what you already have)
    (pl.col("total_post")/pl.col("account_age")).alias("post_frequency_per_year"),
    
    # Per month (divide year by 12)
    (pl.col("total_post")/(pl.col("account_age") * 12)).alias("post_frequency_per_month"),
    
    # Per day (multiply year by 365)
    (pl.col("total_post")/(pl.col("account_age") * 365)).alias("post_frequency_per_day")
])

# %%
df_cleaned
# Out:
# shape: (961, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ from_user ┆ profile_l ┆ account_a ┆ is_buzzer ┆ … ┆ followers ┆ post_freq ┆ post_freq ┆ post_fre │
# │ name      ┆ ink       ┆ ge        ┆ ---       ┆   ┆ ---       ┆ uency_per ┆ uency_per ┆ quency_p │
# │ ---       ┆ ---       ┆ ---       ┆ i64       ┆   ┆ i64       ┆ _year     ┆ _month    ┆ er_day   │
# │ str       ┆ str       ┆ i64       ┆           ┆   ┆           ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Ayudihuta ┆ https://t ┆ 9         ┆ 1         ┆ … ┆ 641       ┆ 2233.3333 ┆ 186.11111 ┆ 6.118721 │
# │ nkecil    ┆ witter.co ┆           ┆           ┆   ┆           ┆ 33        ┆ 1         ┆          │
# │           ┆ m/Ayudihu ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ tan…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ bang_ouz7 ┆ https://t ┆ 7         ┆ 1         ┆ … ┆ 15        ┆ 327.42857 ┆ 27.285714 ┆ 0.897065 │
# │ 1         ┆ witter.co ┆           ┆           ┆   ┆           ┆ 1         ┆           ┆          │
# │           ┆ m/bang_ou ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ z71       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ KowuLaode ┆ https://t ┆ 2         ┆ 1         ┆ … ┆ 98        ┆ 5050.0    ┆ 420.83333 ┆ 13.83561 │
# │ 341884    ┆ witter.co ┆           ┆           ┆   ┆           ┆           ┆ 3         ┆ 6        │
# │           ┆ m/KowuLao ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ de3…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Manusia2B ┆ https://t ┆ 4         ┆ 1         ┆ … ┆ 669       ┆ 22425.0   ┆ 1868.75   ┆ 61.43835 │
# │           ┆ witter.co ┆           ┆           ┆   ┆           ┆           ┆           ┆ 6        │
# │           ┆ m/Manusia ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 2B        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ PutraMahe ┆ https://t ┆ 2         ┆ 0         ┆ … ┆ 58        ┆ 1293.0    ┆ 107.75    ┆ 3.542466 │
# │ s59       ┆ witter.co ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ m/PutraMa ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ hes…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Zaenal587 ┆ https://t ┆ 2         ┆ 1         ┆ … ┆ 1014      ┆ 9900.0    ┆ 825.0     ┆ 27.12328 │
# │ 88427     ┆ witter.co ┆           ┆           ┆   ┆           ┆           ┆           ┆ 8        │
# │           ┆ m/Zaenal5 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 878…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ bharataso ┆ https://t ┆ 11        ┆ 1         ┆ … ┆ 82        ┆ 18.181818 ┆ 1.515152  ┆ 0.049813 │
# │ im        ┆ witter.co ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ m/bharata ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ soi…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ BustoniFi ┆ https://t ┆ 5         ┆ 1         ┆ … ┆ 66        ┆ 821.2     ┆ 68.433333 ┆ 2.249863 │
# │ kri4      ┆ witter.co ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ m/Bustoni ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ Fik…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ SETYAKI22 ┆ https://t ┆ 4         ┆ 1         ┆ … ┆ 21413     ┆ 27225.0   ┆ 2268.75   ┆ 74.58904 │
# │ 965702    ┆ witter.co ┆           ┆           ┆   ┆           ┆           ┆           ┆ 1        │
# │           ┆ m/SETYAKI ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 229…      ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Venus1970 ┆ https://t ┆ 5         ┆ 1         ┆ … ┆ 53        ┆ 2600.0    ┆ 216.66666 ┆ 7.123288 │
# │ 2         ┆ witter.co ┆           ┆           ┆   ┆           ┆           ┆ 7         ┆          │
# │           ┆ m/Venus19 ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 702       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_cleaned['is_buzzer'].value_counts()
# Out:
# shape: (2, 2)
# ┌───────────┬───────┐
# │ is_buzzer ┆ count │
# │ ---       ┆ ---   │
# │ i64       ┆ u32   │
# ╞═══════════╪═══════╡
# │ 0         ┆ 381   │
# │ 1         ┆ 580   │
# └───────────┴───────┘

# %% [markdown]
# ## Data Modelling

# %%
features_to_normalize = ["account_age","followers", "total_post", "post_frequency_per_year", "post_frequency_per_month"]
X = df_cleaned.select(features_to_normalize).to_pandas()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=features_to_normalize)

y=df_cleaned.select("is_buzzer").to_pandas()
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %% [markdown]
# ### Decision Tree

# %%
dt = DecisionTreeClassifier(
    random_state=42,
    class_weight=None,
    criterion='entropy',
    max_depth=5,
    min_samples_leaf=4,
    min_samples_split=15    
)


# Fit GridSearchCV
dt.fit(X_train, y_train)


# Make predictions with best model
y_pred = dt.predict(X_test)

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import confusion_matrix
# Print classification report
print("\nClassification Report with Best Parameters:")
print(classification_report(y_test, y_pred))

# Feature importance
feature_importance = pd.DataFrame({
    'feature': features_to_normalize,
    'importance': dt.feature_importances_
}).sort_values('importance', ascending=False)

print("\nFeature Importance:")
print(feature_importance)

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report with Best Parameters:
#               precision    recall  f1-score   support
#
#            0       0.56      0.54      0.55        78
#            1       0.69      0.71      0.70       115
#
#     accuracy                           0.64       193
#    macro avg       0.63      0.63      0.63       193
# weighted avg       0.64      0.64      0.64       193
#
#
# Feature Importance:
#                     feature  importance
# 3   post_frequency_per_year    0.457674
# 2                total_post    0.277143
# 4  post_frequency_per_month    0.199352
# 1                 followers    0.042755
# 0               account_age    0.023075
#
# Confusion Matrix:
# [[42 36]
#  [33 82]]

# %% [markdown]
# ### Random Forest

# %%
# Create final model with best parameters
best_rf = RandomForestClassifier(
    class_weight=None,
    max_depth=10,
    max_features='sqrt',
    min_samples_leaf=2,
    min_samples_split=15,
    n_estimators=200,
    random_state=42
)

# Train on full training data
best_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=15,
#                        n_estimators=200, random_state=42)

# %% [markdown]
# ### Classification Report

# %%
# Make predictions
y_pred = best_rf.predict(X_test)
y_pred_proba = best_rf.predict_proba(X_test)

# Get performance metrics
from sklearn.metrics import classification_report, confusion_matrix
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Feature importance
feature_importance = pd.DataFrame({
    'feature': features_to_normalize,
    'importance': best_rf.feature_importances_
}).sort_values('importance', ascending=False)

print("\nFeature Importance:")
print(feature_importance)

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.44      0.48        78
#            1       0.66      0.74      0.70       115
#
#     accuracy                           0.62       193
#    macro avg       0.60      0.59      0.59       193
# weighted avg       0.61      0.62      0.61       193
#
#
# Feature Importance:
#                     feature  importance
# 4  post_frequency_per_month    0.267261
# 3   post_frequency_per_year    0.256467
# 2                total_post    0.205086
# 1                 followers    0.183330
# 0               account_age    0.087856
#
# Confusion Matrix:
# [[34 44]
#  [30 85]]

# %% [markdown]
# ### XGBoost

# %%
# Create model with best parameters
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic',
    random_state=42,
    colsample_bytree=0.8,
    gamma=0.2,
    learning_rate=0.01,
    max_depth=5,
    min_child_weight=3,
    n_estimators=100,
    subsample=0.9,
    use_label_encoder=False,
    eval_metric='logloss'  
)

# Try SMOTE for balancing
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

# Train with balanced data and multiple evaluation metrics
eval_set = [(X_train_balanced, y_train_balanced), (X_test, y_test)]
xgb_model.fit(
    X_train_balanced, 
    y_train_balanced,
    eval_set=eval_set,
    early_stopping_rounds=50,
    verbose=True
)

# Make predictions and evaluate
y_pred = xgb_model.predict(X_test)
y_pred_proba = xgb_model.predict_proba(X_test)
# Out:
# [0]	validation_0-logloss:0.69128	validation_1-logloss:0.69256
# [1]	validation_0-logloss:0.68959	validation_1-logloss:0.69194
# [2]	validation_0-logloss:0.68808	validation_1-logloss:0.69061
# [3]	validation_0-logloss:0.68672	validation_1-logloss:0.68969
# [4]	validation_0-logloss:0.68501	validation_1-logloss:0.68866
# [5]	validation_0-logloss:0.68330	validation_1-logloss:0.68824
# [6]	validation_0-logloss:0.68183	validation_1-logloss:0.68748
# [7]	validation_0-logloss:0.68033	validation_1-logloss:0.68656
# [8]	validation_0-logloss:0.67893	validation_1-logloss:0.68590
# [9]	validation_0-logloss:0.67755	validation_1-logloss:0.68534
# [10]	validation_0-logloss:0.67610	validation_1-logloss:0.68440
# [11]	validation_0-logloss:0.67458	validation_1-logloss:0.68341
# [12]	validation_0-logloss:0.67302	validation_1-logloss:0.68292
# [13]	validation_0-logloss:0.67161	validation_1-logloss:0.68228
# [14]	validation_0-logloss:0.67024	validation_1-logloss:0.68142
# [15]	validation_0-logloss:0.66868	validation_1-logloss:0.68109
# [16]	validation_0-logloss:0.66728	validation_1-logloss:0.68057
# [17]	validation_0-logloss:0.66581	validation_1-logloss:0.68013
# [18]	validation_0-logloss:0.66430	validation_1-logloss:0.67957
# [19]	validation_0-logloss:0.66306	validation_1-logloss:0.67888
# [20]	validation_0-logloss:0.66168	validation_1-logloss:0.67859
# [21]	validation_0-logloss:0.66044	validation_1-logloss:0.67832
# [22]	validation_0-logloss:0.65912	validation_1-logloss:0.67772
# [23]	validation_0-logloss:0.65787	validation_1-logloss:0.67685
# [24]	validation_0-logloss:0.65654	validation_1-logloss:0.67633
# [25]	validation_0-logloss:0.65523	validation_1-logloss:0.67571
# [26]	validation_0-logloss:0.65411	validation_1-logloss:0.67540
# [27]	validation_0-logloss:0.65271	validation_1-logloss:0.67489
# [28]	validation_0-logloss:0.65157	validation_1-logloss:0.67404
# [29]	validation_0-logloss:0.65047	validation_1-logloss:0.67392
# [30]	validation_0-logloss:0.64929	validation_1-logloss:0.67366
# [31]	validation_0-logloss:0.64814	validation_1-logloss:0.67329
# [32]	validation_0-logloss:0.64692	validation_1-logloss:0.67313
# [33]	validation_0-logloss:0.64581	validation_1-logloss:0.67265
# [34]	validation_0-logloss:0.64485	validation_1-logloss:0.67218
# [35]	validation_0-logloss:0.64365	validation_1-logloss:0.67148
# [36]	validation_0-logloss:0.64253	validation_1-logloss:0.67088
# [37]	validation_0-logloss:0.64136	validation_1-logloss:0.67068
# [38]	validation_0-logloss:0.64023	validation_1-logloss:0.67015
# [39]	validation_0-logloss:0.63914	validation_1-logloss:0.66984
# [40]	validation_0-logloss:0.63786	validation_1-logloss:0.66951
# [41]	validation_0-logloss:0.63680	validation_1-logloss:0.66916
# [42]	validation_0-logloss:0.63578	validation_1-logloss:0.66872
# [43]	validation_0-logloss:0.63477	validation_1-logloss:0.66823
# [44]	validation_0-logloss:0.63364	validation_1-logloss:0.66774
# [45]	validation_0-logloss:0.63272	validation_1-logloss:0.66712
# [46]	validation_0-logloss:0.63171	validation_1-logloss:0.66661
# [47]	validation_0-logloss:0.63080	validation_1-logloss:0.66596
# [48]	validation_0-logloss:0.62989	validation_1-logloss:0.66569
# [49]	validation_0-logloss:0.62888	validation_1-logloss:0.66555
# [50]	validation_0-logloss:0.62787	validation_1-logloss:0.66516
# [51]	validation_0-logloss:0.62704	validation_1-logloss:0.66488
# [52]	validation_0-logloss:0.62608	validation_1-logloss:0.66435
# [53]	validation_0-logloss:0.62526	validation_1-logloss:0.66396
# [54]	validation_0-logloss:0.62421	validation_1-logloss:0.66371
# [55]	validation_0-logloss:0.62332	validation_1-logloss:0.66366
# [56]	validation_0-logloss:0.62252	validation_1-logloss:0.66342
# [57]	validation_0-logloss:0.62164	validation_1-logloss:0.66318
# [58]	validation_0-logloss:0.62083	validation_1-logloss:0.66269
# [59]	validation_0-logloss:0.61985	validation_1-logloss:0.66271
# [60]	validation_0-logloss:0.61886	validation_1-logloss:0.66245
# [61]	validation_0-logloss:0.61781	validation_1-logloss:0.66218
# [62]	validation_0-logloss:0.61696	validation_1-logloss:0.66171
# [63]	validation_0-logloss:0.61611	validation_1-logloss:0.66142
# [64]	validation_0-logloss:0.61513	validation_1-logloss:0.66113
# [65]	validation_0-logloss:0.61427	validation_1-logloss:0.66070
# [66]	validation_0-logloss:0.61334	validation_1-logloss:0.66030
# [67]	validation_0-logloss:0.61267	validation_1-logloss:0.66005
# [68]	validation_0-logloss:0.61188	validation_1-logloss:0.66003
# [69]	validation_0-logloss:0.61104	validation_1-logloss:0.66010
# [70]	validation_0-logloss:0.61031	validation_1-logloss:0.66024
# [71]	validation_0-logloss:0.60938	validation_1-logloss:0.65979
# [72]	validation_0-logloss:0.60843	validation_1-logloss:0.65932
# [73]	validation_0-logloss:0.60774	validation_1-logloss:0.65931
# [74]	validation_0-logloss:0.60707	validation_1-logloss:0.65912
# [75]	validation_0-logloss:0.60625	validation_1-logloss:0.65893
# [76]	validation_0-logloss:0.60550	validation_1-logloss:0.65868
# [77]	validation_0-logloss:0.60479	validation_1-logloss:0.65838
# [78]	validation_0-logloss:0.60409	validation_1-logloss:0.65830
# [79]	validation_0-logloss:0.60336	validation_1-logloss:0.65806
# [80]	validation_0-logloss:0.60258	validation_1-logloss:0.65787
# [81]	validation_0-logloss:0.60179	validation_1-logloss:0.65779
# [82]	validation_0-logloss:0.60097	validation_1-logloss:0.65752
# [83]	validation_0-logloss:0.60013	validation_1-logloss:0.65780
# [84]	validation_0-logloss:0.59940	validation_1-logloss:0.65748
# [85]	validation_0-logloss:0.59861	validation_1-logloss:0.65780
# [86]	validation_0-logloss:0.59797	validation_1-logloss:0.65781
# [87]	validation_0-logloss:0.59723	validation_1-logloss:0.65789
# [88]	validation_0-logloss:0.59658	validation_1-logloss:0.65787
# [89]	validation_0-logloss:0.59587	validation_1-logloss:0.65785
# [90]	validation_0-logloss:0.59506	validation_1-logloss:0.65778
# [91]	validation_0-logloss:0.59441	validation_1-logloss:0.65784
# [92]	validation_0-logloss:0.59361	validation_1-logloss:0.65770
# [93]	validation_0-logloss:0.59290	validation_1-logloss:0.65768
# [94]	validation_0-logloss:0.59228	validation_1-logloss:0.65793
# [95]	validation_0-logloss:0.59160	validation_1-logloss:0.65795
# [96]	validation_0-logloss:0.59101	validation_1-logloss:0.65784
# [97]	validation_0-logloss:0.59015	validation_1-logloss:0.65763
# [98]	validation_0-logloss:0.58960	validation_1-logloss:0.65772
# [99]	validation_0-logloss:0.58885	validation_1-logloss:0.65793

# %%
# Print detailed evaluation
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55        78
#            1       0.69      0.59      0.64       115
#
#     accuracy                           0.60       193
#    macro avg       0.59      0.60      0.59       193
# weighted avg       0.61      0.60      0.60       193
#
#
# Confusion Matrix:
# [[47 31]
#  [47 68]]
